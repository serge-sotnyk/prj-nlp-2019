# %% [markdown]
# ## Заголовки новин
#
# ### 1. Форматування
#
# [The Associated Press Stylebook](https://www.amazon.com/Associated-Press-Stylebook-2017-Briefing/dp/0465093043/) - це посібник зі стилю, яким часто послуговуються журналісти по всьому світу. Він рекомендує такі правила форматування заголовків:
# 1. З великої літери потрібно писати іменники, займенники, дієслова, прикметники, прислівники та підрядні сполучники. Якщо слово написане через дефіс, велику літеру потрібно додати для кожної частинки слова (наприклад, правильно "Self-Reflection", а не "Self-reflection").
# 2. З великої літери потрібно писати перше і останнє слово заголовку, незалежно від частини мови.
# 3. З маленької літери потрібно писати всі інші частини мови: артиклі/визначники, сурядні сполучники, прийменники, частки, вигуки.
#
# **Завдання:**
# 1. напишіть програму, яка форматує заголовки за вказаними правилами
# 2. проженіть вашу програму на [корпусі заголовків з The Examiner](examiner-headlines.txt)
# 3. збережіть програму та файл із відформатованими заголовками у директорії з вашим іменем
# 4. скільки заголовків у корпусі було відформатовано правильно? (скільки заголовків залишились незмінними?)
#
# Зверніть увагу, що ваша програма повинна правильно розрізняти прийменники та підрядні сполучники. Наприклад, `Do as you want` => `Do As You Want` (бо "as" тут є сполучником), but `How to use a Macbook as a table` => `How to Use a Macbook as a Table` (бо "as" тут є прийменником).

# %%
import spacy


IN_FILE1 = '../../../tasks/02-structural-linguistics/examiner-headlines.txt'
OUT_FILE1 = 'examiner-headlines_processed.txt'

        
def ap_capitalize(text, model) -> str:
    """Associated Press Word Capitalizer"""
    
    # Tokenize & tag headline
    doc = model(text)

    processed_tokens = []
    capitalized_headline = ""
    text_len = len(doc)
    
    """1. З великої літери потрібно писати іменники, займенники, дієслова, прикметники, 
    прислівники та підрядні сполучники. 
    
    1.1. Якщо слово написане через дефіс, велику літеру 
    потрібно додати для кожної частинки слова (наприклад, правильно "Self-Reflection", 
    а не "Self-reflection")."""
    capitalize_pos = ['NOUN', 'PRON', 'VERB', 'ADJ', 'ADV', 'SCONJ']

    
    """2. З великої літери потрібно писати перше і останнє слово заголовку, незалежно 
    від частини мови."""    
    
    """З маленької літери потрібно писати всі інші частини мови: артиклі/визначники, 
    сурядні сполучники, прийменники, частки, вигуки."""
    decapitalize_pos = ['DET', 'CCONJ', 'ADP', 'PART', 'INTJ']
    
    
    """Зверніть увагу, що ваша програма повинна правильно розрізняти прийменники та 
    підрядні сполучники. Наприклад, `Do as you want` => `Do As You Want` (бо "as" тут 
    є сполучником), but `How to use a Macbook as a table` => `How to Use a Macbook as 
    a Table` (бо "as" тут є прийменником)."""
    capitalize_dep = ['mark']
    
    # Capitalize
    for i in range(0, text_len):
        # Apply rule 2
        if i == 0 or i == text_len-1:
            processed_tokens.append(doc[i].text_with_ws.capitalize())
        # Apply rules 1 & 4
        elif doc[i].pos_ in capitalize_pos or doc[i].dep_ in capitalize_dep:
            processed_tokens.append(doc[i].text_with_ws.capitalize())
        # Apply rule 3
        elif doc[i].pos_ in decapitalize_pos:
            processed_tokens.append(doc[i].text_with_ws)
        # All exceptions logically fall under Rule 3 as well
        else:
            processed_tokens.append(doc[i].text_with_ws)
    
    # Return reassembled headline
    return ''.join([w for w in processed_tokens])


def main(in_file, out_file):
    
    nlp = spacy.load('en_core_web_md')
    i = open(in_file, 'r')
    o = open(out_file, 'w+')
    
    changed_counter = 0
    total_counter = 0
    
    for raw_headline in i.readlines():
        processed_headline = ap_capitalize(raw_headline, nlp)
        o.write(processed_headline)
        
        total_counter += 1
        if processed_headline != raw_headline:
            changed_counter += 1
        
        # Debug before launching on full list :) 
        # if changed_counter >= 50:
        #     break
            
    print("Headlines capitalized differently: {0}/{1}: {2}%".format(
                                        changed_counter,
                                        total_counter,
                                        changed_counter / total_counter * 100))
    
    i.close()
    o.close()
        
main(IN_FILE1, OUT_FILE1)
# Out:
# Headlines capitalized differently: 4264/5000: 85.28%

# %% [markdown]
# ### 2. Вірусні новини
#
# У статті [Automatic Extraction of News Values from Headline Text](http://www.aclweb.org/anthology/E17-4007) описано основні ознаки заголовків, які кидаються в очі і змушують читача таки прочитати новину:
# 1. наявність імен людей, назв компаній тощо
# 2. емоційне забарвлення
# 3. ступені порівняння
# 4. близькість
# 5. елемент несподіванки
# 6. унікальність
#
# **Завдання:**
# 1. Напишіть програму, яка аналізує заголовок за першими трьома ознаками (у спрощеній формі)
#    * Чи є в заголовку іменовані стуності?
#    * Чи є заголовок позитивно чи негативно забарвлений?
#    * Чи є в заголовку прикметники та прислівники вищого і найвищого ступенів порівняння?
# 2. Проженіть вашу програму на [корпусі заголовків з The Examiner](examiner-headlines.txt). Для кожної з трьох ознак, визначте відсоток заголовків у корпусі, які її мають.
# 3. Збережіть програму та пораховану статистику в директорії з вашим іменем.
#
# Додаткова інформація:
# - Типи сутностей, які впливають на "вірусність" заголовка, виберіть самостійно.
# - Для визначення емоційного забарвлення, використайте [SentiWordNet](http://sentiwordnet.isti.cnr.it/). Наприклад, можна перевірити, що середнє значення позитивності/негативності слова у заголовку перевищує 0.5. Для визначення середнього значення можна брати до п'яти перших значень слова з такою частиною мови. Будьте креативними та експериментуйте.
#
# ### Джерела
#
# Ви можете використати будь-яку мову програмування та будь-яку NLP-бібліотеку.
#
# Набір заголовків взятий із https://www.kaggle.com/therohk/examine-the-examiner.""

# %%
import spacy
from nltk.corpus import sentiwordnet as swn


IN_FILE2 = '../../../tasks/02-structural-linguistics/examiner-headlines.txt'
OUT_FILE2 = 'examiner-headlines_virality_scores.csv'


def virality_score(text, model) -> tuple:
    """Програма, яка аналізує заголовок такими ознаками:
    
    returns: tuple: (bool: contains_ne,
                     bool: contains_st,
                     bool: contains_cs)"""
    
    # Tokenize & tag headline
    doc = model(text)
    
    contains_ne = False
    contains_st = False
    contains_cs = False
    
    for token in doc:
        """Чи є в заголовку іменовані стуності?"""
        # Contains PROPN (TB: NP)
        if token.tag_ in ['NNP']:
            contains_ne = True
    
        """Чи є заголовок позитивно чи негативно забарвлений?"""
        # Map parts of speech processed by SentiWordNet
        pos_map = {
            'NOUN' : 'n',
            'VERB' : 'v',
            'ADJ' : 'a',
            'ADV' : 'r'
        }
        
        # and only work with eligible tokens
        # specifically ignore proper nouns becuase they aren't in SWN
        if token.pos_ in pos_map and token.tag_ not in ['NNP']:
            
            # Build request to SentiWordNet
            swn_request = token.lemma_ + '.' + pos_map[token.pos_] + '.' + '01'
            
            try:
                s = swn.senti_synset(swn_request)
                if max(s.pos_score(), s.neg_score()) > 0.5:
                    contains_st = True
            except:
                print("Word not found in SWN: {0}: {1}".format(token.lemma_, token.pos_))

            

        """Чи є в заголовку прикметники та прислівники вищого і 
        найвищого ступенів порівняння?"""
        # Contains TB: RBR, RBS, JJR, JJS
        if token.tag_ in ['RBR', 'RBS', 'JJR', 'JJS']:
            contains_cs = True
    
    return (contains_ne, contains_st, contains_cs)
        
    
def main(in_file, out_file):
    
    nlp = spacy.load('en_core_web_md')
    i = open(in_file, 'r')
    o = open(out_file, 'w+')
    
    total_counter = 0
    
    for headline in i.readlines():
        flags = virality_score(headline, nlp)
        o.write('"' + headline.rstrip() + '",' 
                + str(int(flags[0])) + ','
                + str(int(flags[1])) + ','
                + str(int(flags[2])) + '\n'
               )
        
        total_counter += 1
        
        # if total_counter >= 10:
        #    break
            
    print("Headlines processed: {0}".format(total_counter))
    
    i.close()
    o.close()
        
main(IN_FILE2, OUT_FILE2)
# Out:
# Word not found in SWN: could: VERB
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: repurpos: VERB
# Word not found in SWN: where: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: sf: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: fiancée: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: psych: NOUN
# Word not found in SWN: psych: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: must: VERB
# Word not found in SWN: fi: NOUN
# Word not found in SWN: vegetarian: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: ADJ
# Word not found in SWN: athletic: NOUN
# Word not found in SWN: recruiting: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: diy: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: focaccia: NOUN
# Word not found in SWN: %: NOUN
# Word not found in SWN: uva: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: customization: NOUN
# Word not found in SWN: chick: ADJ
# Word not found in SWN: cupcak: VERB
# Word not found in SWN: holiday: ADJ
# Word not found in SWN: duggar: NOUN
# Word not found in SWN: winter: ADJ
# Word not found in SWN: skirted: ADJ
# Word not found in SWN: online: ADV
# Word not found in SWN: featurette: NOUN
# Word not found in SWN: must: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: 2-under: NOUN
# Word not found in SWN: bestselling: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: zombiu: NOUN
# Word not found in SWN: alone: NOUN
# Word not found in SWN: something: NOUN
# Word not found in SWN: unglue: NOUN
# Word not found in SWN: role: ADJ
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: ter: NOUN
# Word not found in SWN: %: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: carb: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: pitbull: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: battlefield: VERB
# Word not found in SWN: cofee: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: 6th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: superhero: NOUN
# Word not found in SWN: why: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: sentencing: NOUN
# Word not found in SWN: celebrity: ADJ
# Word not found in SWN: pairwise: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: crumble: NOUN
# Word not found in SWN: guia: NOUN
# Word not found in SWN: pollos: NOUN
# Word not found in SWN: airstrike: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: up: NOUN
# Word not found in SWN: must: VERB
# Word not found in SWN: shocker: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: srt_01e: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: undead: NOUN
# Word not found in SWN: would: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: should: VERB
# Word not found in SWN: nutrition: VERB
# Word not found in SWN: giveaway: ADV
# Word not found in SWN: why: ADV
# Word not found in SWN: should: VERB
# Word not found in SWN: could: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: thanksgiv: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: pacquiao: NOUN
# Word not found in SWN: midseason: NOUN
# Word not found in SWN: 12th: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: slay: NOUN
# Word not found in SWN: that: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: 7-year: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: sports: ADJ
# Word not found in SWN: fundraising: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 10th: NOUN
# Word not found in SWN: craigslist: NOUN
# Word not found in SWN: canine: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: other: NOUN
# Word not found in SWN: mano: NOUN
# Word not found in SWN: ios7: NOUN
# Word not found in SWN: ios: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: starshine: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: 6-month: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 4x4: NOUN
# Word not found in SWN: mixtape: NOUN
# Word not found in SWN: everyone: NOUN
# Word not found in SWN: playfulness: ADJ
# Word not found in SWN: eco: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: selfie: NOUN
# Word not found in SWN: airmass: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: modder: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: would: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: other: NOUN
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: fun: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: tatoo: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: tat: ADJ
# Word not found in SWN: 8th: NOUN
# Word not found in SWN: non: ADJ
# Word not found in SWN: nab: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 4th: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: 19th: NOUN
# Word not found in SWN: retail: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: mpg: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: artsy: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: ups: NOUN
# Word not found in SWN: leaderboard: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: because: VERB
# Word not found in SWN: savvy: ADJ
# Word not found in SWN: guacamole: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 22nd: NOUN
# Word not found in SWN: sci: NOUN
# Word not found in SWN: fi: NOUN
# Word not found in SWN: something: NOUN
# Word not found in SWN: everyone: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: summer: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: upcom: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: cater: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: off: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: psych: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: off: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: holistic: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 3rd: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: photographer: VERB
# Word not found in SWN: 7th: NOUN
# Word not found in SWN: viedo: NOUN
# Word not found in SWN: 25th: NOUN
# Word not found in SWN: volkswagen: NOUN
# Word not found in SWN: must: VERB
# Word not found in SWN: faf: NOUN
# Word not found in SWN: holiday: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: where: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: upstate: ADJ
# Word not found in SWN: something: NOUN
# Word not found in SWN: everyone: NOUN
# Word not found in SWN: fun: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: foul: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 4th: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: cogs: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: bailout: NOUN
# Word not found in SWN: dumpl: VERB
# Word not found in SWN: 3rd: NOUN
# Word not found in SWN: your: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: mentoring: NOUN
# Word not found in SWN: standout: NOUN
# Word not found in SWN: could: VERB
# Word not found in SWN: upcom: VERB
# Word not found in SWN: d3: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: don't: ADV
# Word not found in SWN: other: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: night: VERB
# Word not found in SWN: anything: NOUN
# Word not found in SWN: railgun: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: mommie: NOUN
# Word not found in SWN: mailroom: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: politic: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: odd: NOUN
# Word not found in SWN: 30th: NOUN
# Word not found in SWN: redux: NOUN
# Word not found in SWN: would: VERB
# Word not found in SWN: disturbutor: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: should: VERB
# Word not found in SWN: walkthrough: NOUN
# Word not found in SWN: denial: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: shapely: ADV
# Word not found in SWN: re: VERB
# Word not found in SWN: invent: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: that: ADJ
# Word not found in SWN: 2-year: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 1-day: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: smartphone: NOUN
# Word not found in SWN: 4th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: ongo: VERB
# Word not found in SWN: pg: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: immigrant: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: workplace: ADJ
# Word not found in SWN: paparazzi: NOUN
# Word not found in SWN: -pic: NOUN
# Word not found in SWN: 5th: NOUN
# Word not found in SWN: promo: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: understand: NOUN
# Word not found in SWN: tomatofest: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: bl: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: q&a: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: fellow: ADJ
# Word not found in SWN: where: ADV
# Word not found in SWN: tidepool: ADJ
# Word not found in SWN: ferrari: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: grassroot: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: soulmate: ADJ
# Word not found in SWN: thru: NOUN
# Word not found in SWN: politic: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: dater: NOUN
# Word not found in SWN: fundraising: NOUN
# Word not found in SWN: earning: NOUN
# Word not found in SWN: 25th: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: cohousing: NOUN
# Word not found in SWN: unplugged: ADJ
# Word not found in SWN: biker: NOUN
# Word not found in SWN: slutty: ADJ
# Word not found in SWN: online: ADV
# Word not found in SWN: retail: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: 250th: ADJ
# Word not found in SWN: supercar: NOUN
# Word not found in SWN: racecar: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: heartworm: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: chuggin: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: heartbroken: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: eld: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: diy: ADJ
# Word not found in SWN: because: NOUN
# Word not found in SWN: that: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: trampire: NOUN
# Word not found in SWN: diss: NOUN
# Word not found in SWN: oglethorpe: NOUN
# Word not found in SWN: which: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: cheese: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: non: ADJ
# Word not found in SWN: peek: ADJ
# Word not found in SWN: 3d: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: must: VERB
# Word not found in SWN: that: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: n: ADJ
# Word not found in SWN: sporting: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: slimm: VERB
# Word not found in SWN: crumpet: VERB
# Word not found in SWN: summer: ADJ
# Word not found in SWN: 5th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: wanna: VERB
# Word not found in SWN: luminaid: VERB
# Word not found in SWN: bareback: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: nite: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: manga: NOUN
# Word not found in SWN: 67th: ADJ
# Word not found in SWN: other: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: networking: NOUN
# Word not found in SWN: tecnologie: NOUN
# Word not found in SWN: statut: VERB
# Word not found in SWN: transgender: NOUN
# Word not found in SWN: raping: NOUN
# Word not found in SWN: indoor: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: touch: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: sounion: NOUN
# Word not found in SWN: spinach: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: when: ADV
# Word not found in SWN: where: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: why: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: rid: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 12th: NOUN
# Word not found in SWN: must: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: measle: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: sox: NOUN
# Word not found in SWN: grandaddie: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: 11th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: dine: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: badass: ADJ
# Word not found in SWN: shadows: NOUN
# Word not found in SWN: thon: NOUN
# Word not found in SWN: something: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: bethenny: NOUN
# Word not found in SWN: kelloggs: NOUN
# Word not found in SWN: cereal: VERB
# Word not found in SWN: diy: ADJ
# Word not found in SWN: decorating: NOUN
# Word not found in SWN: donate: NOUN
# Word not found in SWN: proceed: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: remix: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: remix: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: anyone: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: poppy: ADJ
# Word not found in SWN: outdoor: NOUN
# Word not found in SWN: character: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: purrfect: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: rexist360: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: sincere: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: why: ADV
# Word not found in SWN: why: ADV
# Word not found in SWN: escitalopram: NOUN
# Word not found in SWN: clarin: NOUN
# Word not found in SWN: cable: ADJ
# Word not found in SWN: thrif: NOUN
# Word not found in SWN: %: NOUN
# Word not found in SWN: o'hearne: NOUN
# Word not found in SWN: pre: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: media: NOUN
# Word not found in SWN: enhancing: NOUN
# Word not found in SWN: fun: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: rspca: ADJ
# Word not found in SWN: upgrade: ADJ
# Word not found in SWN: at: ADV
# Word not found in SWN: memorial: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: heatwave: NOUN
# Word not found in SWN: off: NOUN
# Word not found in SWN: could: VERB
# Word not found in SWN: non: ADJ
# Word not found in SWN: overreach: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: zeer: NOUN
# Word not found in SWN: hacking: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: gamer: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: newletter: NOUN
# Word not found in SWN: parenting: NOUN
# Word not found in SWN: flatform: NOUN
# Word not found in SWN: up: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: that: ADJ
# Word not found in SWN: pre: NOUN
# Word not found in SWN: kannada: ADJ
# Word not found in SWN: spay: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: ios: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: arsenal: ADJ
# Word not found in SWN: £: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: michigan: ADJ
# Word not found in SWN: spr: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: x75: NOUN
# Word not found in SWN: tubines: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: rehire: NOUN
# Word not found in SWN: something: NOUN
# Word not found in SWN: gov: NOUN
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: mbfw: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: finding: ADJ
# Word not found in SWN: %: NOUN
# Word not found in SWN: pbuh: NOUN
# Word not found in SWN: way: VERB
# Word not found in SWN: glitzy: ADJ
# Word not found in SWN: pre: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: 8th: NOUN
# Word not found in SWN: speak: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: creme: NOUN
# Word not found in SWN: creme: NOUN
# Word not found in SWN: expungement: ADJ
# Word not found in SWN: everday: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: %: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: staffing: NOUN
# Word not found in SWN: showcas: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: up: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: episode: VERB
# Word not found in SWN: fun: ADJ
# Word not found in SWN: holidaze: NOUN
# Word not found in SWN: rainy: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: jihad: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: stoke: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: triathlon: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 9-year: ADJ
# Word not found in SWN: 10th: NOUN
# Word not found in SWN: 18th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: showcase: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: decomposed: ADJ
# Word not found in SWN: up: NOUN
# Word not found in SWN: chivalry: ADJ
# Word not found in SWN: fed: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: donating: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: cornerback: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: tastiest: ADJ
# Word not found in SWN: superfood: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: dem: NOUN
# Word not found in SWN: chicagoan: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: may: VERB
# Word not found in SWN: followup: ADJ
# Word not found in SWN: ebook: NOUN
# Word not found in SWN: floundering: NOUN
# Word not found in SWN: non: ADJ
# Word not found in SWN: moving: NOUN
# Word not found in SWN: non: ADJ
# Word not found in SWN: exoplanetary: ADJ
# Word not found in SWN: extrasolar: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: android: ADJ
# Word not found in SWN: odd: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: heavyweight: ADJ
# Word not found in SWN: xbox.com: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: retro: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: job: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: else: ADV
# Word not found in SWN: blacklight: NOUN
# Word not found in SWN: homeschool: VERB
# Word not found in SWN: superfight: NOUN
# Word not found in SWN: up: NOUN
# Word not found in SWN: outfest: ADJ
# Word not found in SWN: nor'easter: NOUN
# Word not found in SWN: devastated: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: dredging: NOUN
# Word not found in SWN: navigable: NOUN
# Word not found in SWN: vs: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: 4th: NOUN
# Word not found in SWN: paranormal: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: must: VERB
# Word not found in SWN: revist: VERB
# Word not found in SWN: hoodie: NOUN
# Word not found in SWN: 10th: NOUN
# Word not found in SWN: pre: NOUN
# Word not found in SWN: where: ADV
# Word not found in SWN: cougar: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: else: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: spay: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: hi: ADJ
# Word not found in SWN: def: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: passholder: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: app: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: credential: ADJ
# Word not found in SWN: thank: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: when: ADV
# Word not found in SWN: pre: NOUN
# Word not found in SWN: 18th: NOUN
# Word not found in SWN: fo: VERB
# Word not found in SWN: trespassing: NOUN
# Word not found in SWN: subgenre: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: athletic: NOUN
# Word not found in SWN: everyone: NOUN
# Word not found in SWN: #: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: non: ADJ
# Word not found in SWN: cancellable: ADJ
# Word not found in SWN: non: ADJ
# Word not found in SWN: holiday: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: i.d: NOUN
# Word not found in SWN: that: ADJ
# Word not found in SWN: der: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: should: VERB
# Word not found in SWN: schmoopie: NOUN
# Word not found in SWN: drunken: NOUN
# Word not found in SWN: overall: ADV
# Word not found in SWN: sacada: NOUN
# Word not found in SWN: yoplait: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 13th: NOUN
# Word not found in SWN: prior: ADV
# Word not found in SWN: holiday: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADV
# Word not found in SWN: pelvic: NOUN
# Word not found in SWN: desert: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: heiress: ADJ
# Word not found in SWN: dinosaur: VERB
# Word not found in SWN: that: ADJ
# Word not found in SWN: homeschool: NOUN
# Word not found in SWN: complete: NOUN
# Word not found in SWN: outstand: VERB
# Word not found in SWN: pre: NOUN
# Word not found in SWN: algae: ADJ
# Word not found in SWN: biodiesel: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: implantable: ADJ
# Word not found in SWN: broadband: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: pre: NOUN
# Word not found in SWN: gymnastic: NOUN
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: baserunner: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: screenwrit: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: spiking: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: why: ADV
# Word not found in SWN: 15th: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: summer: ADJ
# Word not found in SWN: homeschooler: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: weathercast: NOUN
# Word not found in SWN: euthaniz: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: whose: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: hydrating: NOUN
# Word not found in SWN: carb: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: spooktacular: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: eco: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: guest: VERB
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: quarterfinal: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: hacking: NOUN
# Word not found in SWN: 21st: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: claus: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: floral: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: dos: VERB
# Word not found in SWN: knockout: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: pre: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: husker: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: winter: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: contibut: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: barking: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: what: NOUN
# Word not found in SWN: vegan: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: goaltending: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: malware: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: redshirt: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: which: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 2-year: NOUN
# Word not found in SWN: superfan: NOUN
# Word not found in SWN: 113th: ADJ
# Word not found in SWN: precinct: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: celebs: VERB
# Word not found in SWN: online: ADV
# Word not found in SWN: when: ADV
# Word not found in SWN: live: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: sync: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: able: VERB
# Word not found in SWN: app: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: osu: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 3d: ADJ
# Word not found in SWN: syncytial: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: everyone: NOUN
# Word not found in SWN: q&a: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: other: NOUN
# Word not found in SWN: precip: NOUN
# Word not found in SWN: underrepresent: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 99er: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: role: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: #: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: showcase: VERB
# Word not found in SWN: everything: NOUN
# Word not found in SWN: diy: NOUN
# Word not found in SWN: touring: NOUN
# Word not found in SWN: doorbuster: VERB
# Word not found in SWN: setlist: NOUN
# Word not found in SWN: dumbing: NOUN
# Word not found in SWN: %: NOUN
# Word not found in SWN: week: ADJ
# Word not found in SWN: mayan: ADJ
# Word not found in SWN: other: NOUN
# Word not found in SWN: showcase: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: spanked: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: should: VERB
# Word not found in SWN: fun: ADJ
# Word not found in SWN: everyone: NOUN
# Word not found in SWN: specter: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 28th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: healthfully: ADV
# Word not found in SWN: bowhunter: NOUN
# Word not found in SWN: bigs: ADV
# Word not found in SWN: powerball: NOUN
# Word not found in SWN: photobombs: NOUN
# Word not found in SWN: breakout: ADJ
# Word not found in SWN: holiday: ADJ
# Word not found in SWN: 20th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: racy: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 21st: NOUN
# Word not found in SWN: nachos: NOUN
# Word not found in SWN: why: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: unlog: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: soulmate: NOUN
# Word not found in SWN: midwest: ADJ
# Word not found in SWN: something: NOUN
# Word not found in SWN: %: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: workin: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: agrue: VERB
# Word not found in SWN: leaguer: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: fun: ADJ
# Word not found in SWN: app: NOUN
# Word not found in SWN: valedictorian: ADJ
# Word not found in SWN: creationist: NOUN
# Word not found in SWN: what: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: partier: NOUN
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: download: NOUN
# Word not found in SWN: lynch: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: nurse: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: which: ADJ
# Word not found in SWN: up: NOUN
# Word not found in SWN: firelight: VERB
# Word not found in SWN: mcdonald: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: anything: NOUN
# Word not found in SWN: sl: VERB
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: gameplay: VERB
# Word not found in SWN: resourc: VERB
# Word not found in SWN: celebrity: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: anyone: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: must: VERB
# Word not found in SWN: when: ADV
# Word not found in SWN: mentorship: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: jump: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: eroehr: NOUN
# Word not found in SWN: giveth: VERB
# Word not found in SWN: taketh: VERB
# Word not found in SWN: pre: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: mmorpg: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: where: ADV
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: clicking: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: feely: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: frontman: NOUN
# Word not found in SWN: frontman: NOUN
# Word not found in SWN: bully: ADV
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: gory: NOUN
# Word not found in SWN: garlic: ADJ
# Word not found in SWN: booty: ADJ
# Word not found in SWN: where: ADV
# Word not found in SWN: workshop: VERB
# Word not found in SWN: 14th: NOUN
# Word not found in SWN: n: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: media: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: else: ADV
# Word not found in SWN: 4th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: may: VERB
# Word not found in SWN: easier: ADV
# Word not found in SWN: could: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: must: VERB
# Word not found in SWN: p.m.: NOUN
# Word not found in SWN: aloud: NOUN
# Word not found in SWN: 7-year: ADJ
# Word not found in SWN: resetting: NOUN
# Word not found in SWN: cowork: VERB
# Word not found in SWN: up: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: could: VERB
# Word not found in SWN: showcas: VERB
# Word not found in SWN: other: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 24th: NOUN
# Word not found in SWN: download: NOUN
# Word not found in SWN: disappoint: NOUN
# Word not found in SWN: gamer: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: odd: NOUN
# Word not found in SWN: p.m.: NOUN
# Word not found in SWN: why: ADV
# Word not found in SWN: fiddling: NOUN
# Word not found in SWN: qb: NOUN
# Word not found in SWN: bailout: NOUN
# Word not found in SWN: that: ADJ
# Word not found in SWN: app: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 5.0l: NOUN
# Word not found in SWN: condemns: VERB
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: would: VERB
# Word not found in SWN: 17th: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: non: ADJ
# Word not found in SWN: holiday: ADJ
# Word not found in SWN: passenger: ADJ
# Word not found in SWN: overheard: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: could: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: electronic: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 12th: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: motorsport: NOUN
# Word not found in SWN: 8-year: ADJ
# Word not found in SWN: upcom: VERB
# Word not found in SWN: everyday: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: finding: ADJ
# Word not found in SWN: researching: NOUN
# Word not found in SWN: gameplay: NOUN
# Word not found in SWN: webcast: NOUN
# Word not found in SWN: examiner: ADJ
# Word not found in SWN: sibl: VERB
# Word not found in SWN: meto: NOUN
# Word not found in SWN: 3d: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: ghosthunting: NOUN
# Word not found in SWN: arab: ADJ
# Word not found in SWN: youtube.com: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: budgeting: NOUN
# Word not found in SWN: foolin: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: castmember: NOUN
# Word not found in SWN: 11th: NOUN
# Word not found in SWN: politic: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: ADJ
# Word not found in SWN: mmva: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: prospecting: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: viewership: NOUN
# Word not found in SWN: reunite: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: may: VERB
# Word not found in SWN: artsy: ADJ
# Word not found in SWN: craftsy: NOUN
# Word not found in SWN: 27th: NOUN
# Word not found in SWN: weiner: NOUN
# Word not found in SWN: undead: NOUN
# Word not found in SWN: musky: NOUN
# Word not found in SWN: could: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: which: ADJ
# Word not found in SWN: because: NOUN
# Word not found in SWN: wwe: NOUN
# Word not found in SWN: furture: NOUN
# Word not found in SWN: 49er: NOUN
# Word not found in SWN: preorder: NOUN
# Word not found in SWN: when: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: partier: NOUN
# Word not found in SWN: where: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: cha: NOUN
# Word not found in SWN: jewellry: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: leftover: VERB
# Word not found in SWN: upcom: VERB
# Word not found in SWN: other: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: where: ADV
# Word not found in SWN: politic: NOUN
# Word not found in SWN: non: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: rpg: NOUN
# Word not found in SWN: sb281: NOUN
# Word not found in SWN: 1st: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: parenting: NOUN
# Word not found in SWN: concoct: NOUN
# Word not found in SWN: everybody: NOUN
# Word not found in SWN: workplace: ADJ
# Word not found in SWN: peek: ADJ
# Word not found in SWN: redneck: ADJ
# Word not found in SWN: waterpark: NOUN
# Word not found in SWN: must: VERB
# Word not found in SWN: diabete: NOUN
# Word not found in SWN: health: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: online: ADV
# Word not found in SWN: measle: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 9th: NOUN
# Word not found in SWN: 11th: NOUN
# Word not found in SWN: politic: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: 18th: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: 3ds: NOUN
# Word not found in SWN: curation: NOUN
# Word not found in SWN: redesign: NOUN
# Word not found in SWN: women: NOUN
# Word not found in SWN: 18th: NOUN
# Word not found in SWN: 26th: NOUN
# Word not found in SWN: should: VERB
# Word not found in SWN: br: VERB
# Word not found in SWN: epigenetic: ADJ
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: wrote: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: %: NOUN
# Word not found in SWN: heartworm: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 29th: NOUN
# Word not found in SWN: proclamation: VERB
# Word not found in SWN: wildfir: VERB
# Word not found in SWN: that: ADJ
# Word not found in SWN: rehab: NOUN
# Word not found in SWN: upcoming: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: 8x: NOUN
# Word not found in SWN: ne: VERB
# Word not found in SWN: hurtin: NOUN
# Word not found in SWN: gameplay: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: app: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: 49er: NOUN
# Word not found in SWN: rival: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: good-: VERB
# Word not found in SWN: largest: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: mellifera: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: rosé: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: fundraising: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: dysmorphic: NOUN
# Word not found in SWN: vintage: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: iso: NOUN
# Word not found in SWN: funeral: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 16th: NOUN
# Word not found in SWN: lookalike: ADJ
# Word not found in SWN: why: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: arthouse: NOUN
# Word not found in SWN: tamoxifen: VERB
# Word not found in SWN: could: VERB
# Word not found in SWN: how: ADV
# Word not found in SWN: tos: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: gymnastic: NOUN
# Word not found in SWN: 99er: NOUN
# Word not found in SWN: rewind: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: manioc: VERB
# Word not found in SWN: pirao: ADJ
# Word not found in SWN: tuna: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: winter: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: online: ADV
# Word not found in SWN: that: ADV
# Word not found in SWN: slideshow: NOUN
# Word not found in SWN: online: ADV
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 5-star: ADJ
# Word not found in SWN: %: NOUN
# Word not found in SWN: evermore: VERB
# Word not found in SWN: bailout: NOUN
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: would: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: counterculture: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: everyday: NOUN
# Word not found in SWN: visual: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: eco: NOUN
# Word not found in SWN: hd: NOUN
# Word not found in SWN: what: NOUN
# Word not found in SWN: biker: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: cal: ADJ
# Word not found in SWN: ratify: NOUN
# Word not found in SWN: fun: ADJ
# Word not found in SWN: announce: NOUN
# Word not found in SWN: app: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: misportray: VERB
# Word not found in SWN: may: VERB
# Word not found in SWN: corneal: NOUN
# Word not found in SWN: may: VERB
# Word not found in SWN: reunite: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: what: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: newlyw: VERB
# Word not found in SWN: texting: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: docu: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: realignment: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: 2-year: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: 18th: NOUN
# Word not found in SWN: inspire: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: online: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: warm: NOUN
# Word not found in SWN: up: NOUN
# Word not found in SWN: def: NOUN
# Word not found in SWN: could: VERB
# Word not found in SWN: politic: NOUN
# Word not found in SWN: 'd: VERB
# Word not found in SWN: should: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: stun: NOUN
# Word not found in SWN: other: NOUN
# Word not found in SWN: what: ADJ
# Word not found in SWN: would: VERB
# Word not found in SWN: med: ADJ
# Word not found in SWN: what: ADJ
# Word not found in SWN: yeasayer: NOUN
# Word not found in SWN: staunch: NOUN
# Word not found in SWN: where: ADV
# Word not found in SWN: latest: ADV
# Word not found in SWN: backup: ADJ
# Word not found in SWN: when: ADV
# Word not found in SWN: could: VERB
# Word not found in SWN: could: VERB
# Word not found in SWN: labrador: ADJ
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: lower: ADV
# Word not found in SWN: polling: NOUN
# Word not found in SWN: infographic: ADJ
# Word not found in SWN: networking: NOUN
# Word not found in SWN: 15th: NOUN
# Word not found in SWN: could: VERB
# Word not found in SWN: meac: ADJ
# Word not found in SWN: muss: ADJ
# Word not found in SWN: 29th: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: that: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: would: VERB
# Word not found in SWN: midweek: ADJ
# Word not found in SWN: 49er: NOUN
# Word not found in SWN: birther: NOUN
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: decision: VERB
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: -PRON-: ADJ
# Word not found in SWN: rehab: NOUN
# Word not found in SWN: online: NOUN
# Word not found in SWN: doing: NOUN
# Word not found in SWN: lead: ADJ
# Word not found in SWN: 14th: NOUN
# Word not found in SWN: how: ADV
# Word not found in SWN: -PRON-: ADJ
# Headlines processed: 5000

# %%
"""6C приземляється на плече, перекочуючись, пролітає метрів п’ятдесят 
і витягується на снігу за кілька кроків від забризканої палаючими 
уламками посадкової смуги."""

h1 = "The plane lands on its shoulder, rolling, flies fifty meters forward and stretches itself on the snow near the runway peppered with burning fragments"

# adp in mark = cap

nlp = spacy.load('en_core_web_md')
doc = nlp(h1)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop, token.sentiment)
# Out:
# The the DET DT det Xxx True False 0.0
# plane plane NOUN NN nsubj xxxx True False 0.0
# lands land VERB VBZ ROOT xxxx True False 0.0
# on on ADP IN prep xx True False 0.0
# its -PRON- ADJ PRP$ poss xxx True False 0.0
# shoulder shoulder NOUN NN pobj xxxx True False 0.0
# , , PUNCT , punct , False False 0.0
# rolling rolling NOUN NN advcl xxxx True False 0.0
# , , PUNCT , punct , False False 0.0
# flies fly VERB VBZ conj xxxx True False 0.0
# fifty fifty NUM CD nummod xxxx True False 0.0
# meters meter NOUN NNS npadvmod xxxx True False 0.0
# forward forward ADV RB advmod xxxx True False 0.0
# and and CCONJ CC cc xxx True False 0.0
# stretches stretch VERB VBZ conj xxxx True False 0.0
# itself -PRON- PRON PRP dobj xxxx True False 0.0
# on on ADP IN prep xx True False 0.0
# the the DET DT det xxx True False 0.0
# snow snow NOUN NN pobj xxxx True False 0.0
# near near ADP IN prep xxxx True False 0.0
# the the DET DT det xxx True False 0.0
# runway runway NOUN NN pobj xxxx True False 0.0
# peppered pepper VERB VBN acl xxxx True False 0.0
# with with ADP IN prep xxxx True False 0.0
# burning burn VERB VBG amod xxxx True False 0.0
# fragments fragment NOUN NNS pobj xxxx True False 0.0

# %%
# adp in prep = decap

nlp = spacy.load('en_core_web_sm')
doc = nlp(h6)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)

# %%
# Code rendered unnecessary

import string




def ccap(s):
    """Custom capitalizer"""
    
    # Init empty output string. Strings are immutable 
    # so we can't capitalize in place
    o = ""
    # Include different dashes - just in case
    dashes = "-–—"
    
    for i in range(0, len(s)):
        # Capitalize first char
        if i == 0:
            o += s[i].upper()
        # For all other values, excluding first char
        else:
            # Calitalize after a dash
            if s[i-1] in dashes:
                o += s[i].upper()
            # Keep other letters as they are
            else:
                o += s[i]
    
    return o
