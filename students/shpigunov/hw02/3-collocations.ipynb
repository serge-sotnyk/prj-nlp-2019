# %% [markdown]
# ## Колокації
#
# Одним із важливих аспектів будь-якої природної мови є сполучуваність слів. В англійській мові поняття сполучуваності дуже відчутне і присутнє у всіх мовних структурах: ми кажемо _"make a mistake",_ але _"do a favour";_ ми кажемо _"big surprise",_ але _"great anger";_ ми кажемо _"highly unlikely",_ але _"seriously wrong"._
#
# У цьому завданні вам потрібно дослідити сполучуваність дієслів одного синонімного ряду з прислівниками. Наприклад, ми частіше кажемо _"love somebody dearly", "honor somebody highly",_ але _"admire somebody greatly"._
#
# **Завдання:**
# 1. продовжте синонімний ряд дієслів: _"say", "tell", "speak", "claim", "communicate"_
# 2. напишіть функцію, яка знаходить у реченні дієслово (за складеним раніше синонімним рядом) і витягає усі можливі прислівники на "-ly", якими це дієслово керує
# 3. напишіть програму, яка знайде усі можливі прислівники для наших дієслів у [корпусі блогів](blog2008.txt)
# 4. на виході програма повинна видати десять найчастотніших прислівників для кожного дієслова (разом із частотою). Приклад виводу:
# 	```
# 	say: (loudly, 51), (silently, 45), (quietly, 10)
# 	tell: (quietly, 100), (loudly, 61), (seriously, 5)
# 	```
# 5. збережіть програму та результати аналізу на корпусі (вивід) у директорії з вашим іменем
#
# Синоніми можна знайти у тезаурусах (http://www.thesaurus.com/, https://www.merriam-webster.com/thesaurus) чи [WordNet](http://wordnetweb.princeton.edu/perl/webwn).
#
# Корпус блогів взятий з [Political Blog Corpora](http://www.cs.cmu.edu/~ark/blog-data/).
#
# Ви можете використати будь-яку мову програмування та будь-яку NLP-бібліотеку.
#
# P.S. Зверніть увагу на те, що у природній мові дієслова можуть мати різні форми, а прислівників може бути по декілька.

# %%
"""1. продовжте синонімний ряд дієслів: "say", "tell", "speak", "claim", "communicate"""

# Let's use Wordnet to find synonyms
from nltk.corpus import wordnet 

init_words = ['say', 'tell', 'speak', 'claim', 'communicate']
synonyms = set()

for word in init_words:
    for syn in wordnet.synsets(word):
        if syn.lemmas()[0].name() not in synonyms:
            synonyms.add(syn.lemmas()[0].name().lower())

print(synonyms)

# It's interesting to note that the final list also includes initial words even though
# they were not explicilty added to the resulting list. This has most likely happened
# due to synonymic cross-referencing of each input word.
# Out:
# {'suppose', 'tell', 'order', 'read', 'distinguish', 'title', 'commune', 'say', 'talk', 'state', 'address', 'convey', 'allege', 'call', 'speak', 'pronounce', 'assure', 'communicate', 'claim'}

# %%
import spacy
from pprint import pprint as pp

"""2. напишіть функцію, яка знаходить у реченні дієслово (за складеним раніше синонімним 
рядом) і витягає усі можливі прислівники на "-ly", якими це дієслово керує"""

# Tests 
s1 = "Speak softly and carry a big stick. You will communicate more efficiently."
s2 = "He vehemently alleged that GIF is pronounced as 'JIF'!"

# Init model
nlp = spacy.load('en_core_web_sm')


def find_collocs(verbs, text, model) -> list:
    """Find verb collocations in a text
    
    :rtype list of collocations as tuples [('v1', 'adv1'), ('v2', 'adv2')]"""
    
    # Tokenize!
    doc = model(text)
    verb_collocs = []
    
    # Scan tokens and look for eligible verbs
    for token in doc:
        if token.lemma_ in verbs:
            verb = token.lemma_ 
            
            # Search children of eligible verbs for adverbs
            for child in token.children:
                if child.pos_ == "ADV" and child.text[-2:] == 'ly':
                    advmod = child.lemma_
                    # Add collocation as a tuple to list
                    verb_collocs.append((verb, advmod))
    
    return verb_collocs
            
    
find_collocs(synonyms, s2, nlp)
# Out:
# [('allege', 'vehemently')]

# %%
DEBUG = False
IN_FILE = '../../../tasks/02-structural-linguistics/blog2008.txt'

def analyze(in_file, verbs):
    """3. напишіть програму, яка знайде усі можливі прислівники для наших дієслів у 
    [корпусі блогів](blog2008.txt)"""
    
    nlp = spacy.load('en_core_web_md')
    collocs = []
    colloc_freq = {}
    
    # DEBUG
    limiter = 0
    
    i = open(in_file, 'r')
    
    for line in i.readlines():
        line_collocs = find_collocs(verbs, line, nlp)
        collocs += line_collocs
        
        # DEBUG
        limiter += 1
        if limiter >= 500 and DEBUG:
            break
    
    for colloc in collocs:
        # Split collocation into verb and adverb, for easier comprehension
        verb, adv = colloc[0], colloc[1]
        
        # If the verb is not in the dict, create a new bucket
        if verb not in colloc_freq:
            colloc_freq[verb] = {}
        
        # If the bucket is there, fill it with tallies for adverbs
        if adv not in colloc_freq[verb]:
            colloc_freq[verb][adv] = 1
        else:
            colloc_freq[verb][adv] += 1
    
    return colloc_freq
    
cf = analyze(IN_FILE, synonyms)

pp(cf)
# Out:
# {'address': {'actually': 6,
#              'adequately': 3,
#              'aggressively': 1,
#              'apparently': 1,
#              'appropriately': 1,
#              'barely': 1,
#              'blunderingly': 1,
#              'briefly': 2,
#              'completely': 1,
#              'comprehensively': 1,
#              'concisely': 1,
#              'conspicuously': 1,
#              'contemptuously': 1,
#              'correctly': 1,
#              'definitively': 1,
#              'deftly': 1,
#              'directly': 16,
#              'effectively': 1,
#              'eloquently': 1,
#              'exactly': 1,
#              'explicitly': 1,
#              'finally': 1,
#              'forthrightly': 2,
#              'fully': 2,
#              'hastily': 1,
#              'honestly': 1,
#              'hopefully': 1,
#              'immediately': 2,
#              'indirectly': 1,
#              'intelligently': 1,
#              'memorably': 1,
#              'merely': 1,
#              'mostly': 1,
#              'only': 1,
#              'openly': 1,
#              'peacefully': 1,
#              'personally': 2,
#              'physically': 1,
#              'presumably': 1,
#              'probably': 2,
#              'properly': 2,
#              'publicly': 4,
#              'quickly': 1,
#              'realistically': 1,
#              'really': 4,
#              'respectfully': 1,
#              'separately': 1,
#              'seriously': 1,
#              'shortly': 2,
#              'specifically': 2,
#              'sufficiently': 2,
#              'supposedly': 1,
#              'temporarily': 1,
#              'urgently': 1,
#              'warmly': 1},
#  'allege': {'commonly': 1,
#             'credibly': 1,
#             'directly': 2,
#             'finally': 1,
#             'hypocritically': 1,
#             'officially': 1,
#             'reportedly': 1,
#             'wrongly': 1},
#  'assure': {'basically': 1,
#             'formally': 1,
#             'fully': 2,
#             'loudly': 1,
#             'mostly': 1,
#             'mutually': 2,
#             'periodically': 1,
#             'personally': 1,
#             'plaintively': 1,
#             'practically': 1,
#             'privately': 4,
#             'reportedly': 1,
#             'simultaneously': 1,
#             'unexpectedly': 1,
#             'virtually': 2},
#  'call': {'accidentally': 1,
#           'actually': 16,
#           'additionally': 1,
#           'aggressively': 1,
#           'allegedly': 2,
#           'apparently': 3,
#           'appropriately': 1,
#           'aptly': 1,
#           'arguably': 1,
#           'awkwardly': 1,
#           'badly': 1,
#           'basically': 4,
#           'belatedly': 1,
#           'boldly': 1,
#           'broadly': 1,
#           'calmly': 1,
#           'certainly': 1,
#           'charitably': 1,
#           'cheerily': 1,
#           'clearly': 2,
#           'coincidentally': 1,
#           'commonly': 2,
#           'consistently': 8,
#           'credibly': 1,
#           'crucially': 1,
#           'culturally': 1,
#           'curiously': 1,
#           'daily': 1,
#           'deceptively': 1,
#           'derisively': 4,
#           'desperately': 1,
#           'discreetly': 1,
#           'disparagingly': 1,
#           'early': 1,
#           'easily': 2,
#           'erroneously': 1,
#           'essentially': 4,
#           'euphemistically': 1,
#           'eventually': 1,
#           'exactly': 3,
#           'exasperatedly': 1,
#           'explicitly': 7,
#           'expressly': 1,
#           'falsely': 1,
#           'famously': 8,
#           'finally': 4,
#           'forcefully': 2,
#           'formerly': 1,
#           'generally': 1,
#           'hardly': 3,
#           'hastily': 2,
#           'immediately': 6,
#           'inadvertently': 1,
#           'incidentally': 1,
#           'incorrectly': 2,
#           'inevitably': 1,
#           'initially': 2,
#           'instantly': 1,
#           'intriguingly': 1,
#           'jokingly': 3,
#           'lately': 2,
#           'laughably': 1,
#           'likely': 1,
#           'literally': 1,
#           'locally': 1,
#           'masochistically': 1,
#           'merely': 2,
#           'mistakenly': 2,
#           'mockingly': 1,
#           'mostly': 2,
#           'necessarily': 1,
#           'nominally': 1,
#           'obviously': 3,
#           'officially': 1,
#           'only': 12,
#           'openly': 8,
#           'ordinarily': 1,
#           'originally': 2,
#           'ostensibly': 1,
#           'paradoxically': 1,
#           'particularly': 2,
#           'personally': 3,
#           'piously': 1,
#           'plainly': 1,
#           'pointedly': 1,
#           'potentially': 1,
#           'predictably': 1,
#           'previously': 11,
#           'privately': 1,
#           'promptly': 1,
#           'proudly': 2,
#           'publicly': 8,
#           'quickly': 2,
#           'really': 5,
#           'recently': 7,
#           'reflexively': 2,
#           'regularly': 2,
#           'relentlessly': 1,
#           'remotely': 1,
#           'repeatedly': 11,
#           'reportedly': 2,
#           'responsibly': 1,
#           'revealingly': 1,
#           'rightfully': 1,
#           'rightly': 8,
#           'routinely': 1,
#           'sanctimoniously': 1,
#           'separately': 1,
#           'seriously': 3,
#           'shortly': 1,
#           'simply': 5,
#           'sneeringly': 1,
#           'specifically': 2,
#           'successfully': 1,
#           'succinctly': 1,
#           'suddenly': 1,
#           'supposedly': 1,
#           'surprisingly': 1,
#           'swiftly': 1,
#           'technically': 1,
#           'typically': 1,
#           'ultimately': 1,
#           'undoubtedly': 1,
#           'urgently': 1,
#           'usually': 1,
#           'weirdly': 1,
#           'winkingly': 1,
#           'wishfully': 1,
#           'wittily': 1,
#           'wrongly': 2},
#  'claim': {'absurdly': 3,
#            'actually': 3,
#            'angrily': 1,
#            'apparently': 2,
#            'astonishingly': 1,
#            'audaciously': 1,
#            'baselessly': 1,
#            'bizarrely': 2,
#            'boldly': 1,
#            'brazenly': 1,
#            'certainly': 1,
#            'chronologically': 1,
#            'clearly': 1,
#            'cluelessly': 1,
#            'completely': 1,
#            'consistently': 2,
#            'constantly': 1,
#            'credibly': 3,
#            'disingenuously': 2,
#            'dismissively': 1,
#            'disturbingly': 1,
#            'emphatically': 1,
#            'emptively': 1,
#            'erroneously': 2,
#            'evidently': 1,
#            'explicitly': 1,
#            'falsely': 66,
#            'fiercely': 1,
#            'finally': 1,
#            'formerly': 2,
#            'frequently': 2,
#            'hardly': 1,
#            'idiotically': 1,
#            'illegally': 1,
#            'immediately': 2,
#            'improperly': 1,
#            'inaccurately': 2,
#            'inadvertently': 1,
#            'incessantly': 1,
#            'incorrectly': 3,
#            'indignantly': 2,
#            'inexplicably': 1,
#            'initially': 3,
#            'interestingly': 1,
#            'ironically': 2,
#            'jokingly': 1,
#            'largely': 1,
#            'laughably': 3,
#            'likely': 1,
#            'loudly': 1,
#            'ludicrously': 3,
#            'merely': 1,
#            'mindedly': 1,
#            'notably': 1,
#            'oddly': 1,
#            'only': 1,
#            'openly': 1,
#            'originally': 2,
#            'ostensibly': 1,
#            'patronizingly': 1,
#            'persuasively': 1,
#            'piously': 1,
#            'predictably': 1,
#            'preposterously': 1,
#            'previously': 9,
#            'probably': 1,
#            'publicly': 3,
#            'realistically': 1,
#            'really': 2,
#            'recently': 4,
#            'remotely': 1,
#            'repeatedly': 8,
#            'reportedly': 1,
#            'righteously': 1,
#            'sanctimoniously': 1,
#            'shamelessly': 1,
#            'similarly': 1,
#            'simultaneously': 1,
#            'solemnly': 1,
#            'successfully': 1,
#            'surely': 2,
#            'sweetly': 1,
#            'tantalizingly': 1,
#            'tearfully': 1,
#            'truly': 1,
#            'unbelievably': 1,
#            'vaguely': 2,
#            'widely': 1},
#  'communicate': {'actually': 1,
#                  'apparently': 1,
#                  'daily': 1,
#                  'directly': 3,
#                  'effectively': 3,
#                  'finally': 1,
#                  'freely': 1,
#                  'hopefully': 1,
#                  'loudly': 1,
#                  'poorly': 1,
#                  'privately': 1,
#                  'quickly': 1,
#                  'really': 1,
#                  'regularly': 1},
#  'convey': {'accurately': 3,
#             'clearly': 1,
#             'fully': 2,
#             'only': 1,
#             'privately': 1,
#             'sharply': 1,
#             'strongly': 1,
#             'usually': 2},
#  'distinguish': {'adequately': 1,
#                  'clearly': 1,
#                  'generally': 2,
#                  'literally': 1,
#                  'politically': 1,
#                  'precisely': 2},
#  'order': {'apparently': 1,
#            'blindly': 1,
#            'directly': 1,
#            'famously': 1,
#            'fully': 1,
#            'immediately': 2,
#            'merely': 1,
#            'personally': 1,
#            'possibly': 1,
#            'publicly': 2,
#            'quickly': 1,
#            'really': 1,
#            'recently': 1,
#            'reportedly': 1,
#            'simply': 1},
#  'pronounce': {'correctly': 1, 'officially': 1, 'only': 1, 'suddenly': 1},
#  'read': {'accurately': 1,
#           'actually': 18,
#           'alternatively': 1,
#           'apparently': 10,
#           'avidly': 2,
#           'barely': 1,
#           'carefully': 6,
#           'certainly': 3,
#           'clearly': 1,
#           'closely': 3,
#           'correctly': 11,
#           'critically': 1,
#           'currently': 1,
#           'daily': 1,
#           'easily': 2,
#           'especially': 1,
#           'groovily': 1,
#           'ironically': 1,
#           'lately': 1,
#           'methodically': 1,
#           'narrowly': 1,
#           'obsessively': 1,
#           'obviously': 2,
#           'occasionally': 2,
#           'only': 2,
#           'openly': 1,
#           'particularly': 2,
#           'personally': 1,
#           'probably': 5,
#           'profitably': 1,
#           'properly': 2,
#           'publicly': 1,
#           'rarely': 3,
#           'really': 4,
#           'recently': 6,
#           'regularly': 6,
#           'religiously': 1,
#           'repeatedly': 1,
#           'seriously': 2,
#           'shortly': 1,
#           'simply': 7,
#           'studiously': 1,
#           'surely': 1,
#           'technically': 1,
#           'thoroughly': 1,
#           'undoubtedly': 1,
#           'unfortunately': 1,
#           'widely': 7},
#  'say': {'absolutely': 6,
#          'absurdly': 1,
#          'accidentally': 2,
#          'acidly': 1,
#          'actually': 74,
#          'additionally': 4,
#          'allegedly': 7,
#          'alternately': 1,
#          'amazingly': 1,
#          'animatedly': 1,
#          'anythingpublicly': 1,
#          'apparently': 6,
#          'approvingly': 1,
#          'automatically': 1,
#          'basically': 36,
#          'bitterly': 1,
#          'blindly': 1,
#          'bluntly': 8,
#          'boldly': 1,
#          'candidly': 1,
#          'casually': 1,
#          'categorically': 3,
#          'certainly': 5,
#          'clearly': 23,
#          'coincidentally': 1,
#          'confidently': 1,
#          'conservatively': 2,
#          'consistently': 8,
#          'constantly': 5,
#          'contemporaneously': 2,
#          'continuously': 1,
#          'conversely': 1,
#          'convincingly': 1,
#          'correctly': 8,
#          'curiously': 1,
#          'currently': 2,
#          'curtly': 1,
#          'defensively': 1,
#          'definitively': 7,
#          'derisively': 2,
#          'differently': 4,
#          'directly': 8,
#          'dismissively': 5,
#          'dryly': 1,
#          'early': 4,
#          'easily': 5,
#          'economically': 1,
#          'effectively': 2,
#          'eloquently': 1,
#          'emphatically': 1,
#          'erroneously': 1,
#          'especially': 2,
#          'essentially': 9,
#          'euphemistically': 2,
#          'eventually': 3,
#          'evidently': 1,
#          'exactly': 3,
#          'explicitly': 38,
#          'factly': 1,
#          'falsely': 3,
#          'famously': 19,
#          'finally': 19,
#          'firmly': 1,
#          'flatly': 9,
#          'forcefully': 1,
#          'frankly': 1,
#          'frequently': 2,
#          'fundamentally': 1,
#          'generally': 1,
#          'genteelly': 1,
#          'graciously': 2,
#          'grimly': 1,
#          'haltingly': 1,
#          'hardly': 1,
#          'honestly': 11,
#          'hypothetically': 4,
#          'immediately': 5,
#          'importantly': 1,
#          'inadvertently': 1,
#          'incidentally': 3,
#          'incorrectly': 1,
#          'independently': 1,
#          'indignantly': 2,
#          'inevitably': 1,
#          'infamously': 1,
#          'initially': 6,
#          'innocently': 1,
#          'instantly': 1,
#          'interestingly': 4,
#          'intially': 1,
#          'ironically': 4,
#          'jokingly': 1,
#          'judiciously': 1,
#          'lately': 2,
#          'legitimately': 1,
#          'likely': 2,
#          'literally': 2,
#          'loudly': 2,
#          'memorably': 1,
#          'merely': 17,
#          'mockingly': 3,
#          'neatly': 1,
#          'necessarily': 4,
#          'nervously': 1,
#          'normally': 3,
#          'notably': 2,
#          'notoriously': 1,
#          'obviously': 4,
#          'officially': 1,
#          'only': 25,
#          'openly': 5,
#          'originally': 5,
#          'overwhelmingly': 1,
#          'particularly': 1,
#          'personally': 1,
#          'piously': 1,
#          'plainly': 3,
#          'plausibly': 1,
#          'pointedly': 1,
#          'politely': 1,
#          'politically': 1,
#          'possibly': 1,
#          'precisely': 2,
#          'predictably': 1,
#          'presumably': 2,
#          'previously': 22,
#          'privately': 17,
#          'probably': 13,
#          'properly': 1,
#          'prophetically': 1,
#          'proudly': 1,
#          'publicly': 36,
#          'purportedly': 1,
#          'quickly': 4,
#          'quietly': 5,
#          'rarely': 1,
#          'really': 31,
#          'recently': 77,
#          'recklessly': 1,
#          'reluctantly': 2,
#          'repeatedly': 55,
#          'reportedly': 10,
#          'respectfully': 2,
#          'responsibly': 1,
#          'rightfully': 1,
#          'rightly': 3,
#          'routinely': 2,
#          'ruefully': 1,
#          'sadly': 1,
#          'safely': 2,
#          'secondly': 2,
#          'seriously': 3,
#          'severely': 1,
#          'sheepishly': 1,
#          'similarly': 12,
#          'similiarly': 1,
#          'simply': 46,
#          'simultaneously': 3,
#          'smugly': 1,
#          'snidely': 1,
#          'somberly': 1,
#          'specifically': 15,
#          'sternly': 5,
#          'straightforwardly': 1,
#          'strikingly': 1,
#          'stupidly': 1,
#          'substantially': 1,
#          'suddenly': 3,
#          'supposedly': 3,
#          'surely': 2,
#          'surprisingly': 4,
#          'technically': 2,
#          'theoretically': 1,
#          'thoughtfully': 1,
#          'throatedly': 1,
#          'triumphantly': 2,
#          'truly': 2,
#          'typically': 1,
#          'ultimately': 2,
#          'unbelievably': 1,
#          'unconsciously': 1,
#          'unequivocally': 6,
#          'unfortunately': 6,
#          'unofficially': 1,
#          'usually': 1,
#          'warmly': 1,
#          'wrongly': 2},
#  'speak': {'abusively': 1,
#            'accurately': 1,
#            'actually': 6,
#            'additionally': 1,
#            'aggressively': 1,
#            'anonymously': 5,
#            'apparently': 1,
#            'authoratively': 1,
#            'badly': 1,
#            'barely': 1,
#            'bluntly': 3,
#            'briefly': 9,
#            'broadly': 5,
#            'brusquely': 1,
#            'candidly': 2,
#            'certainly': 2,
#            'clearly': 6,
#            'comparatively': 3,
#            'compassionately': 1,
#            'competently': 1,
#            'competitively': 1,
#            'confidentially': 1,
#            'consistently': 1,
#            'conspicuously': 1,
#            'constantly': 1,
#            'constitutionally': 1,
#            'correctly': 1,
#            'culturally': 1,
#            'currently': 1,
#            'daily': 1,
#            'darkly': 1,
#            'derisively': 1,
#            'despairingly': 1,
#            'directly': 32,
#            'disdainfully': 1,
#            'dismissively': 1,
#            'effectively': 2,
#            'eloquently': 5,
#            'emotionally': 1,
#            'enthusiastically': 1,
#            'especially': 1,
#            'essentially': 1,
#            'ethically': 1,
#            'exactly': 2,
#            'exclusively': 1,
#            'explicitly': 1,
#            'extemporaneously': 3,
#            'extensively': 1,
#            'favorably': 5,
#            'fiercely': 12,
#            'figuratively': 5,
#            'finally': 6,
#            'forcefully': 5,
#            'frankly': 3,
#            'freely': 5,
#            'frequently': 4,
#            'generally': 9,
#            'gingerly': 1,
#            'glowingly': 2,
#            'haltingly': 2,
#            'harshly': 1,
#            'highly': 3,
#            'historically': 2,
#            'hypothetically': 3,
#            'hysterically': 1,
#            'ideally': 1,
#            'immensely': 1,
#            'imprecisely': 1,
#            'inadvertently': 1,
#            'inartfully': 2,
#            'indiscriminately': 1,
#            'infrequently': 1,
#            'intensely': 1,
#            'lately': 1,
#            'legally': 1,
#            'literally': 2,
#            'loudly': 7,
#            'metaphorically': 2,
#            'morally': 1,
#            'movingly': 1,
#            'naturally': 1,
#            'negatively': 2,
#            'normally': 1,
#            'objectively': 2,
#            'occasionally': 1,
#            'officially': 1,
#            'only': 12,
#            'openly': 8,
#            'overtly': 1,
#            'passionately': 1,
#            'personally': 2,
#            'philosophically': 1,
#            'plainly': 3,
#            'politically': 7,
#            'practically': 2,
#            'presumably': 1,
#            'previously': 6,
#            'privately': 3,
#            'probably': 3,
#            'properly': 1,
#            'publicly': 15,
#            'purely': 1,
#            'quickly': 1,
#            'rarely': 2,
#            'rationally': 1,
#            'really': 4,
#            'recently': 7,
#            'regularly': 1,
#            'relatively': 1,
#            'relentlessly': 1,
#            'repeatedly': 1,
#            'reportedly': 1,
#            'roughly': 1,
#            'simply': 1,
#            'softly': 2,
#            'specifically': 5,
#            'statistically': 2,
#            'strictly': 6,
#            'strongly': 4,
#            'stylistically': 1,
#            'subsequently': 1,
#            'tactically': 1,
#            'technically': 2,
#            'traditionally': 1,
#            'truly': 1,
#            'truthfully': 1,
#            'truthily': 1,
#            'unfortunately': 1,
#            'unsurprisingly': 1,
#            'usually': 2,
#            'willingly': 1},
#  'state': {'absurdly': 1,
#            'accurately': 1,
#            'actually': 1,
#            'adamantly': 1,
#            'additionally': 1,
#            'authoritatively': 1,
#            'baldly': 1,
#            'basically': 2,
#            'bluntly': 7,
#            'briefly': 3,
#            'calmly': 1,
#            'categorically': 2,
#            'clearly': 19,
#            'correctly': 4,
#            'directly': 1,
#            'emphatically': 5,
#            'especially': 2,
#            'essentially': 1,
#            'exactly': 2,
#            'explicitly': 13,
#            'expressly': 2,
#            'falsely': 2,
#            'famously': 2,
#            'finally': 1,
#            'firmly': 1,
#            'flatly': 7,
#            'forcefully': 2,
#            'formally': 1,
#            'forwardly': 1,
#            'frequently': 1,
#            'generically': 1,
#            'honestly': 1,
#            'immediately': 1,
#            'inaccurately': 1,
#            'incorrectly': 3,
#            'intriguingly': 1,
#            'ludicrously': 1,
#            'merely': 2,
#            'naturally': 1,
#            'obscenely': 1,
#            'obviously': 1,
#            'officially': 1,
#            'only': 7,
#            'openly': 1,
#            'persistently': 1,
#            'plainly': 3,
#            'previously': 6,
#            'probably': 1,
#            'properly': 1,
#            'publicly': 22,
#            'really': 1,
#            'recently': 6,
#            'repeatedly': 5,
#            'rightly': 2,
#            'separately': 1,
#            'shortly': 1,
#            'simply': 7,
#            'specifically': 4,
#            'subtly': 1,
#            'suggestively': 1,
#            'uncategorically': 1,
#            'unequivocally': 13,
#            'virtually': 2},
#  'suppose': {'apparently': 1,
#              'evidently': 1,
#              'hypothetically': 1,
#              'incidentally': 1,
#              'nominally': 1,
#              'only': 2,
#              'originally': 2,
#              'ostensibly': 1,
#              'presumably': 1,
#              'really': 2,
#              'significantly': 1,
#              'simply': 1},
#  'talk': {'actively': 1,
#           'actually': 7,
#           'anonymously': 1,
#           'apparently': 2,
#           'approvingly': 1,
#           'badly': 1,
#           'beautifully': 1,
#           'blithely': 1,
#           'brazenly': 1,
#           'briefly': 1,
#           'broadly': 1,
#           'certainly': 1,
#           'clearly': 5,
#           'concretely': 1,
#           'consistently': 2,
#           'constantly': 5,
#           'cordially': 1,
#           'daily': 2,
#           'directly': 14,
#           'effectively': 1,
#           'endlessly': 3,
#           'especially': 1,
#           'essentially': 1,
#           'evidently': 1,
#           'exactly': 2,
#           'exclusively': 1,
#           'explicitly': 1,
#           'extensively': 2,
#           'finally': 3,
#           'firmly': 1,
#           'forcefully': 1,
#           'frankly': 1,
#           'gamely': 1,
#           'glowingly': 1,
#           'gravely': 1,
#           'honestly': 2,
#           'incessantly': 1,
#           'increasingly': 1,
#           'interestingly': 1,
#           'literally': 1,
#           'mainly': 1,
#           'merely': 2,
#           'mostly': 3,
#           'namely': 1,
#           'nationally': 1,
#           'necessarily': 1,
#           'obviously': 4,
#           'occasionally': 1,
#           'only': 9,
#           'openly': 7,
#           'outwardly': 1,
#           'particularly': 1,
#           'passionately': 1,
#           'periodically': 2,
#           'permanently': 2,
#           'personally': 5,
#           'presumably': 1,
#           'probably': 2,
#           'publicly': 6,
#           'purely': 1,
#           'quickly': 1,
#           'rarely': 2,
#           'really': 12,
#           'reasonably': 1,
#           'recently': 4,
#           'regularly': 5,
#           'repeatedly': 6,
#           'responsibly': 1,
#           'rightly': 1,
#           'routinely': 1,
#           'sensibly': 1,
#           'separately': 1,
#           'simply': 2,
#           'softly': 2,
#           'specifically': 5,
#           'stiffly': 1,
#           'substantively': 1,
#           'suddenly': 1,
#           'unconditionally': 2,
#           'unfortunately': 1,
#           'unilaterally': 1,
#           'usually': 1,
#           'vaporously': 1,
#           'virtuously': 1,
#           'voluntarily': 1},
#  'tell': {'absolutely': 2,
#           'accidentally': 2,
#           'actually': 8,
#           'allegedly': 3,
#           'apparently': 4,
#           'barely': 2,
#           'basically': 9,
#           'blithely': 1,
#           'bluntly': 5,
#           'candidly': 1,
#           'casually': 1,
#           'categorically': 1,
#           'certainly': 5,
#           'clearly': 1,
#           'coincidentally': 1,
#           'condescendingly': 1,
#           'confidently': 3,
#           'consistently': 1,
#           'constantly': 3,
#           'continually': 1,
#           'curiously': 1,
#           'defensively': 1,
#           'definitively': 2,
#           'directly': 1,
#           'disingenuously': 1,
#           'dismissively': 2,
#           'dramatically': 1,
#           'early': 1,
#           'easily': 1,
#           'effectively': 3,
#           'especially': 3,
#           'essentially': 4,
#           'eventually': 2,
#           'evidently': 1,
#           'exactly': 3,
#           'explicitly': 7,
#           'expressly': 1,
#           'fairly': 1,
#           'faithfully': 1,
#           'falsely': 2,
#           'famously': 2,
#           'finally': 10,
#           'flatly': 2,
#           'forcefully': 1,
#           'frankly': 2,
#           'gleefully': 1,
#           'grimly': 1,
#           'habitually': 1,
#           'heatedly': 1,
#           'helpfully': 2,
#           'honestly': 3,
#           'indirectly': 1,
#           'infamously': 1,
#           'initially': 4,
#           'innocently': 1,
#           'kindly': 1,
#           'likely': 3,
#           'logically': 1,
#           'loudly': 1,
#           'lovingly': 1,
#           'mindedly': 1,
#           'mostly': 1,
#           'necessarily': 1,
#           'only': 9,
#           'optimistically': 1,
#           'originally': 1,
#           'particularly': 2,
#           'personally': 6,
#           'plausibly': 1,
#           'politely': 1,
#           'possibly': 2,
#           'previously': 1,
#           'privately': 11,
#           'probably': 7,
#           'publicly': 2,
#           'quickly': 2,
#           'readily': 1,
#           'really': 8,
#           'recently': 26,
#           'relatedly': 1,
#           'reliably': 3,
#           'repeatedly': 7,
#           'reportedly': 14,
#           'respectfully': 1,
#           'sadly': 2,
#           'sarcastically': 1,
#           'seriously': 2,
#           'sheepishly': 1,
#           'similarly': 3,
#           'simply': 8,
#           'slowly': 2,
#           'snidely': 1,
#           'solemnly': 1,
#           'specifically': 9,
#           'sternly': 1,
#           'subsequently': 1,
#           'subtly': 1,
#           'suddenly': 2,
#           'supposedly': 1,
#           'ultimately': 2,
#           'unavailingly': 1,
#           'undoubtedly': 1,
#           'unequivocally': 1,
#           'usually': 2,
#           'willingly': 1},
#  'title': {'aptly': 1,
#            'charmingly': 1,
#            'cleverly': 1,
#            'deceptively': 1,
#            'humbly': 1,
#            'innocuously': 1,
#            'recently': 1,
#            'tellingly': 1,
#            'tentatively': 2}}

# %%
from collections import OrderedDict as od
import operator

def print_top_10(cf):
    """4. на виході програма повинна видати десять найчастотніших прислівників для 
    кожного дієслова (разом із частотою). Приклад виводу:
    
    say: (loudly, 51), (silently, 45), (quietly, 10)
    tell: (quietly, 100), (loudly, 61), (seriously, 5)"""
    
    for verb in cf.keys():
        print(verb+': ', end='')
        for adverb in cf[verb].keys():
            x = sorted(cf[verb].items(), key=lambda kv: kv[1], reverse=True)
        i = 0
        while i < len(x) and i < 11:
            print("({0}: {1})".format(x[i][0], x[i][1]), end=' ')
            i += 1
        print()
        
    
print_top_10(cf)
# Out:
# claim: (falsely: 66) (previously: 9) (repeatedly: 8) (recently: 4) (initially: 3) (actually: 3) (absurdly: 3) (credibly: 3) (incorrectly: 3) (publicly: 3) (laughably: 3)
# say: (recently: 77) (actually: 74) (repeatedly: 55) (simply: 46) (explicitly: 38) (basically: 36) (publicly: 36) (really: 31) (only: 25) (clearly: 23) (previously: 22)
# speak: (directly: 32) (publicly: 15) (only: 12) (fiercely: 12) (briefly: 9) (generally: 9) (openly: 8) (politically: 7) (loudly: 7) (recently: 7) (previously: 6)
# call: (actually: 16) (only: 12) (repeatedly: 11) (previously: 11) (rightly: 8) (famously: 8) (openly: 8) (consistently: 8) (publicly: 8) (recently: 7) (explicitly: 7)
# tell: (recently: 26) (reportedly: 14) (privately: 11) (finally: 10) (specifically: 9) (only: 9) (basically: 9) (actually: 8) (really: 8) (simply: 8) (repeatedly: 7)
# talk: (directly: 14) (really: 12) (only: 9) (openly: 7) (actually: 7) (publicly: 6) (repeatedly: 6) (personally: 5) (clearly: 5) (constantly: 5) (regularly: 5)
# distinguish: (precisely: 2) (generally: 2) (clearly: 1) (literally: 1) (politically: 1) (adequately: 1)
# address: (directly: 16) (actually: 6) (publicly: 4) (really: 4) (adequately: 3) (forthrightly: 2) (shortly: 2) (properly: 2) (fully: 2) (specifically: 2) (personally: 2)
# suppose: (only: 2) (really: 2) (originally: 2) (significantly: 1) (evidently: 1) (nominally: 1) (incidentally: 1) (simply: 1) (apparently: 1) (presumably: 1) (hypothetically: 1)
# state: (publicly: 22) (clearly: 19) (unequivocally: 13) (explicitly: 13) (only: 7) (bluntly: 7) (simply: 7) (flatly: 7) (previously: 6) (recently: 6) (repeatedly: 5)
# communicate: (effectively: 3) (directly: 3) (freely: 1) (really: 1) (apparently: 1) (loudly: 1) (hopefully: 1) (daily: 1) (actually: 1) (regularly: 1) (quickly: 1)
# read: (actually: 18) (correctly: 11) (apparently: 10) (simply: 7) (widely: 7) (recently: 6) (carefully: 6) (regularly: 6) (probably: 5) (really: 4) (rarely: 3)
# title: (tentatively: 2) (recently: 1) (cleverly: 1) (aptly: 1) (tellingly: 1) (innocuously: 1) (humbly: 1) (charmingly: 1) (deceptively: 1)
# assure: (privately: 4) (virtually: 2) (fully: 2) (mutually: 2) (formally: 1) (loudly: 1) (plaintively: 1) (basically: 1) (unexpectedly: 1) (mostly: 1) (reportedly: 1)
# order: (publicly: 2) (immediately: 2) (simply: 1) (possibly: 1) (merely: 1) (blindly: 1) (personally: 1) (famously: 1) (fully: 1) (really: 1) (recently: 1)
# convey: (accurately: 3) (usually: 2) (fully: 2) (sharply: 1) (clearly: 1) (only: 1) (privately: 1) (strongly: 1)
# allege: (directly: 2) (credibly: 1) (officially: 1) (hypocritically: 1) (reportedly: 1) (wrongly: 1) (commonly: 1) (finally: 1)
# pronounce: (officially: 1) (suddenly: 1) (only: 1) (correctly: 1)
